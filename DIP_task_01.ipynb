# %% [markdown]
# Task Description
#
#
# In this task, a colored image is loaded and converted from BGR to RGB format. The image is then split into its Red, Green, and Blue components. Next, the colored image is converted to grayscale. Finally, grayscale-to-binary conversion is performed using fixed thresholding. The original image and all intermediate results (RGB channels, grayscale image, and binary image) are displayed for comparison and analysis.

# %%
# --- Step 1: Import libraries ---
import cv2
import matplotlib.pyplot as plt

# %%
# --- Step 2: Read a colored image ---
img = cv2.imread('/content/WhatsApp Image 2026-02-02 at 7.04.25 PM.jpeg')          # Replace with your image name if needed
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert from BGR to RGB for correct colors

# %%
# ---  Convert Grayscale to Binary using Thresholding ---

# Display the original image first, as requested
plt.figure(figsize=(6,5))
plt.title("Original Image (before processing)")
plt.imshow(img) # 'img' is expected to be available from previous cells
plt.axis('off')
plt.show()

# Now perform the original task of this cell
_, binary = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY)

# %%
# --- Step 3: Split into Red, Green, Blue components ---
R, G, B = img[:,:,0], img[:,:,1], img[:,:,2]

# %%
# --- Step 4: Convert to Grayscale ---
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
# --- Step 5: Convert Grayscale to Binary using Thresholding ---
_, binary = cv2.threshold(gray, 128, 255, cv2.THRESH_BINARY)

# %%
# --- Step 6: Display all results ---
plt.figure(figsize=(14,8))

plt.subplot(2,3,1)
plt.title("Original Colored Image")
plt.imshow(img)
plt.axis('off')

plt.subplot(2,3,2)
plt.title("Red Component")
plt.imshow(R, cmap='Reds')
plt.axis('off')

plt.subplot(2,3,3)
plt.title("Green Component")
plt.imshow(G, cmap='Greens')
plt.axis('off')

plt.subplot(2,3,4)
plt.title("Blue Component")
plt.imshow(B, cmap='Blues')
plt.axis('off')

plt.subplot(2,3,5)
plt.title("Grayscale Image")
plt.imshow(gray, cmap='gray')
plt.axis('off')

plt.subplot(2,3,6)
plt.title("Binary Image")
plt.imshow(binary, cmap='gray')
plt.axis('off')

plt.show()
